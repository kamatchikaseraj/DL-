# %%
import nltk
from nltk.corpus import stopwords
import re
import joblib
from keras.preprocessing.text import Tokenizer
import gensim
from keras.preprocessing.sequence import pad_sequences
from sklearn.preprocessing import LabelEncoder
from keras.layers import Embedding
from keras.models import Sequential
from keras.layers import Dense,LSTM,Dropout
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Ex.9/training.1600000.processed.noemoticon.csv",encoding='latin-1',header=None)

# %%
df.head()
# Out:
#    0           1                             2         3                4  \
# 0  0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY  _TheSpecialOne_
# 1  0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY    scotthamilton
# 2  0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY         mattycus
# 3  0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY          ElleCTF
# 4  0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY           Karoli
#
#                                                    5
# 0  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1  is upset that he can't update his Facebook by ...
# 2  @Kenichan I dived many times for the ball. Man...
# 3    my whole body feels itchy and like its on fire
# 4  @nationwideclass no, it's not behaving at all....

# %%
columns=['target','ids','date','flag','user','text']
df.columns=columns
df.head()
# Out:
#    target         ids                          date      flag  \
# 0       0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1       0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2       0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3       0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4       0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
#
#               user                                               text
# 0  _TheSpecialOne_  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1    scotthamilton  is upset that he can't update his Facebook by ...
# 2         mattycus  @Kenichan I dived many times for the ball. Man...
# 3          ElleCTF    my whole body feels itchy and like its on fire
# 4           Karoli  @nationwideclass no, it's not behaving at all....

# %%
df.target.replace({0:'Negative',2:'Neutral',4:'Positive'},inplace=True)
df.head()
# Out:
#      target         ids                          date      flag  \
# 0  Negative  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1  Negative  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2  Negative  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3  Negative  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4  Negative  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
#
#               user                                               text
# 0  _TheSpecialOne_  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1    scotthamilton  is upset that he can't update his Facebook by ...
# 2         mattycus  @Kenichan I dived many times for the ball. Man...
# 3          ElleCTF    my whole body feels itchy and like its on fire
# 4           Karoli  @nationwideclass no, it's not behaving at all....

# %%
import nltk
nltk.download('stopwords')
stop_words=set(stopwords.words('english'))
stop_words.remove('not')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
corpus=[]
for i in range(0,len(df)):
    review=re.sub('@\S+|https?:\S+|http?:\S|[^A-Za-z0-9]+',' ',df['text'][i])
    review=review.lower()
    review=review.split()
    review=[word for word in review if not word in stop_words]
    review=' '.join(review)
    corpus.append(review)

# %%
df.text=corpus
df.head()
# Out:
#      target         ids                          date      flag  \
# 0  Negative  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1  Negative  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2  Negative  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3  Negative  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4  Negative  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
#
#               user                                               text
# 0  _TheSpecialOne_       awww bummer shoulda got david carr third day
# 1    scotthamilton  upset update facebook texting might cry result...
# 2         mattycus  dived many times ball managed save 50 rest go ...
# 3          ElleCTF                   whole body feels itchy like fire
# 4           Karoli                               not behaving mad see

# %%
from sklearn.model_selection import train_test_split
train_df,test_df=train_test_split(df,test_size=0.20,random_state=123)
train_df.head()
# Out:
#            target         ids                          date      flag  \
# 1578903  Positive  2189875205  Tue Jun 16 01:08:25 PDT 2009  NO_QUERY
# 51568    Negative  1679002293  Sat May 02 08:17:21 PDT 2009  NO_QUERY
# 569210   Negative  2207868145  Wed Jun 17 08:29:12 PDT 2009  NO_QUERY
# 71896    Negative  1694083746  Mon May 04 01:00:43 PDT 2009  NO_QUERY
# 405089   Negative  2058584282  Sat Jun 06 15:13:45 PDT 2009  NO_QUERY
#
#                     user                                               text
# 1578903  silent_serenade                   withholding information shae yup
# 51568           tommytrc  uhhh ummmmm yes dear keep coming tweetups prom...
# 569210     nikkikikicoco  amazing time wannqa come home come back suitca...
# 71896            bszafko          ouch wrist hurts gym accident see surgeon
# 405089         carolduff                            going crazy work school

# %%
test_df.head()
# Out:
#            target         ids                          date      flag  \
# 448282   Negative  2068921155  Sun Jun 07 14:56:42 PDT 2009  NO_QUERY
# 1475261  Positive  2065871668  Sun Jun 07 09:27:21 PDT 2009  NO_QUERY
# 132529   Negative  1835774749  Mon May 18 06:43:27 PDT 2009  NO_QUERY
# 182348   Negative  1967121891  Fri May 29 19:00:46 PDT 2009  NO_QUERY
# 907614   Positive  1695846172  Mon May 04 07:04:29 PDT 2009  NO_QUERY
#
#                    user                                               text
# 448282    smiley_sophie                   arm still hurts pulled yesterday
# 1475261  ImmaChocoholic  much outside looking 4 years w energy totally ...
# 132529       drmomentum  yes knew clusterfark way since right phd annou...
# 182348      sweetsheilx            woke feel relieved haha go work 2 hours
# 907614        monmariej  loving hot weather forecast rest week summer a...

# %%
documents = [text.split() for text in train_df.text]
w2v_model = gensim.models.word2vec.Word2Vec(size=300, 
                                            window=7, 
                                            min_count=10, 
                                            workers=8)
w2v_model.build_vocab(documents)
words = w2v_model.wv.vocab.keys()
vocab_size = len(words)
print("Vocab size", vocab_size)
# Out:
# Vocab size 30446

# %%
w2v_model.train(documents, total_examples=len(documents), epochs=30)
# Out:
# (248017780, 279410310)

# %%
w2v_model.wv.most_similar("good")
# Out:
# [('great', 0.6930592060089111),
#  ('goood', 0.5701472759246826),
#  ('bad', 0.5536270141601562),
#  ('nice', 0.5004874467849731),
#  ('gooood', 0.4888903498649597),
#  ('goooood', 0.46977996826171875),
#  ('gooooood', 0.4657142162322998),
#  ('gd', 0.459757536649704),
#  ('rough', 0.4531475007534027),
#  ('fantastic', 0.4445255994796753)]

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(train_df.text)
tokenizer.word_index
# Out:
# {'not': 1,
#  'good': 2,
#  'day': 3,
#  'get': 4,
#  'like': 5,
#  'go': 6,
#  'quot': 7,
#  'today': 8,
#  'work': 9,
#  'love': 10,
#  'going': 11,
#  'got': 12,
#  'lol': 13,
#  'time': 14,
#  'back': 15,
#  'u': 16,
#  'one': 17,
#  'know': 18,
#  'im': 19,
#  'really': 20,
#  'amp': 21,
#  'see': 22,
#  'night': 23,
#  'still': 24,
#  '2': 25,
#  'well': 26,
#  'want': 27,
#  'new': 28,
#  'think': 29,
#  'home': 30,
#  'thanks': 31,
#  'oh': 32,
#  'much': 33,
#  'miss': 34,
#  'need': 35,
#  'last': 36,
#  'morning': 37,
#  'tomorrow': 38,
#  'hope': 39,
#  'great': 40,
#  'twitter': 41,
#  '3': 42,
#  'haha': 43,
#  'feel': 44,
#  'sad': 45,
#  'fun': 46,
#  'wish': 47,
#  'sleep': 48,
#  'right': 49,
#  'would': 50,
#  'bad': 51,
#  'happy': 52,
#  'sorry': 53,
#  'tonight': 54,
#  'come': 55,
#  'make': 56,
#  'way': 57,
#  'getting': 58,
#  'though': 59,
#  'gonna': 60,
#  'nice': 61,
#  'better': 62,
#  'watching': 63,
#  'yeah': 64,
#  'wait': 65,
#  'bed': 66,
#  'could': 67,
#  'week': 68,
#  'school': 69,
#  'people': 70,
#  'hate': 71,
#  'days': 72,
#  'even': 73,
#  'hey': 74,
#  'next': 75,
#  '4': 76,
#  'yes': 77,
#  'weekend': 78,
#  'lt': 79,
#  'awesome': 80,
#  'dont': 81,
#  'thank': 82,
#  'never': 83,
#  'soon': 84,
#  'cant': 85,
#  'take': 86,
#  'long': 87,
#  'working': 88,
#  'little': 89,
#  'first': 90,
#  'wanna': 91,
#  'please': 92,
#  'say': 93,
#  'best': 94,
#  'everyone': 95,
#  'show': 96,
#  'tired': 97,
#  'ok': 98,
#  'life': 99,
#  'sick': 100,
#  'watch': 101,
#  'done': 102,
#  'feeling': 103,
#  '1': 104,
#  'let': 105,
#  'always': 106,
#  'sure': 107,
#  'thing': 108,
#  'x': 109,
#  'already': 110,
#  'another': 111,
#  'friends': 112,
#  'cool': 113,
#  'us': 114,
#  'something': 115,
#  'find': 116,
#  'man': 117,
#  'guys': 118,
#  'ready': 119,
#  'made': 120,
#  'looking': 121,
#  'yay': 122,
#  'phone': 123,
#  'yet': 124,
#  'look': 125,
#  'went': 126,
#  'hours': 127,
#  'house': 128,
#  'ur': 129,
#  'movie': 130,
#  'ever': 131,
#  'pretty': 132,
#  'maybe': 133,
#  'n': 134,
#  'trying': 135,
#  'omg': 136,
#  'away': 137,
#  'summer': 138,
#  'tweet': 139,
#  'finally': 140,
#  'old': 141,
#  '5': 142,
#  'early': 143,
#  'help': 144,
#  'amazing': 145,
#  'damn': 146,
#  'follow': 147,
#  'things': 148,
#  'someone': 149,
#  'lost': 150,
#  'guess': 151,
#  'left': 152,
#  'friend': 153,
#  'keep': 154,
#  'big': 155,
#  'year': 156,
#  'wow': 157,
#  'thought': 158,
#  'bit': 159,
#  'hot': 160,
#  'missed': 161,
#  'ya': 162,
#  'nothing': 163,
#  'rain': 164,
#  'sucks': 165,
#  'bored': 166,
#  'glad': 167,
#  'girl': 168,
#  'try': 169,
#  'start': 170,
#  'tell': 171,
#  'also': 172,
#  'birthday': 173,
#  'baby': 174,
#  'looks': 175,
#  'live': 176,
#  'coming': 177,
#  'sun': 178,
#  'weather': 179,
#  'later': 180,
#  'two': 181,
#  'song': 182,
#  'w': 183,
#  'actually': 184,
#  'hear': 185,
#  'ugh': 186,
#  'saw': 187,
#  'party': 188,
#  'stuff': 189,
#  'makes': 190,
#  'waiting': 191,
#  'excited': 192,
#  'might': 193,
#  'play': 194,
#  'hard': 195,
#  'game': 196,
#  'said': 197,
#  'god': 198,
#  'yesterday': 199,
#  'thats': 200,
#  'since': 201,
#  'world': 202,
#  'hi': 203,
#  'gotta': 204,
#  'lot': 205,
#  'late': 206,
#  'around': 207,
#  'mom': 208,
#  'music': 209,
#  'car': 210,
#  'sounds': 211,
#  'many': 212,
#  'check': 213,
#  'b': 214,
#  'luck': 215,
#  'friday': 216,
#  'must': 217,
#  'head': 218,
#  'found': 219,
#  'r': 220,
#  'cold': 221,
#  'give': 222,
#  'job': 223,
#  'read': 224,
#  'call': 225,
#  'sunday': 226,
#  'aww': 227,
#  'making': 228,
#  'beautiful': 229,
#  'gone': 230,
#  'may': 231,
#  'talk': 232,
#  'missing': 233,
#  'com': 234,
#  'put': 235,
#  'anything': 236,
#  'monday': 237,
#  'poor': 238,
#  'stop': 239,
#  'woke': 240,
#  'least': 241,
#  'till': 242,
#  'almost': 243,
#  'leave': 244,
#  'hair': 245,
#  'family': 246,
#  'lunch': 247,
#  'free': 248,
#  'use': 249,
#  'tho': 250,
#  'okay': 251,
#  'times': 252,
#  'cute': 253,
#  'far': 254,
#  'food': 255,
#  'hurts': 256,
#  'end': 257,
#  'iphone': 258,
#  'wanted': 259,
#  'mean': 260,
#  'hour': 261,
#  'listening': 262,
#  'eat': 263,
#  'dinner': 264,
#  '10': 265,
#  'funny': 266,
#  'everything': 267,
#  'enjoy': 268,
#  'gt': 269,
#  'followers': 270,
#  'anyone': 271,
#  'finished': 272,
#  'playing': 273,
#  'welcome': 274,
#  'sweet': 275,
#  'believe': 276,
#  'shit': 277,
#  'forward': 278,
#  'thinking': 279,
#  '6': 280,
#  'without': 281,
#  'video': 282,
#  'cause': 283,
#  'hahaha': 284,
#  'totally': 285,
#  'mine': 286,
#  'coffee': 287,
#  'stupid': 288,
#  'outside': 289,
#  'enough': 290,
#  'real': 291,
#  'buy': 292,
#  'ill': 293,
#  'every': 294,
#  'anymore': 295,
#  'didnt': 296,
#  'wrong': 297,
#  'p': 298,
#  'probably': 299,
#  'room': 300,
#  'weeks': 301,
#  'tweets': 302,
#  'eating': 303,
#  'ha': 304,
#  'place': 305,
#  'tv': 306,
#  'money': 307,
#  'stay': 308,
#  'c': 309,
#  'dad': 310,
#  'wants': 311,
#  'busy': 312,
#  'sooo': 313,
#  'win': 314,
#  'following': 315,
#  'xx': 316,
#  'lovely': 317,
#  'saturday': 318,
#  '30': 319,
#  'seen': 320,
#  'pic': 321,
#  'kinda': 322,
#  'class': 323,
#  'whole': 324,
#  'says': 325,
#  'taking': 326,
#  '8': 327,
#  'came': 328,
#  '7': 329,
#  'kids': 330,
#  'hopefully': 331,
#  'beach': 332,
#  'crazy': 333,
#  'headache': 334,
#  'exam': 335,
#  'super': 336,
#  'name': 337,
#  'took': 338,
#  'half': 339,
#  'awww': 340,
#  'guy': 341,
#  'news': 342,
#  'true': 343,
#  'hello': 344,
#  'hell': 345,
#  'idea': 346,
#  'goodnight': 347,
#  'post': 348,
#  'book': 349,
#  'face': 350,
#  'years': 351,
#  'ago': 352,
#  'able': 353,
#  'lots': 354,
#  'run': 355,
#  'else': 356,
#  'forgot': 357,
#  'meet': 358,
#  'reading': 359,
#  'full': 360,
#  'shopping': 361,
#  'leaving': 362,
#  'either': 363,
#  'sitting': 364,
#  'rest': 365,
#  'girls': 366,
#  'computer': 367,
#  'send': 368,
#  'used': 369,
#  'ah': 370,
#  'feels': 371,
#  'soo': 372,
#  'boo': 373,
#  'hurt': 374,
#  'cuz': 375,
#  'blog': 376,
#  'remember': 377,
#  'seems': 378,
#  'raining': 379,
#  'hehe': 380,
#  'alone': 381,
#  'watched': 382,
#  'office': 383,
#  'dog': 384,
#  'talking': 385,
#  'fuck': 386,
#  'hit': 387,
#  'heart': 388,
#  'btw': 389,
#  'tried': 390,
#  'trip': 391,
#  'needs': 392,
#  'heard': 393,
#  'stuck': 394,
#  'mind': 395,
#  'internet': 396,
#  'kind': 397,
#  'course': 398,
#  'www': 399,
#  'part': 400,
#  'wont': 401,
#  'started': 402,
#  'boy': 403,
#  'seeing': 404,
#  'online': 405,
#  'quite': 406,
#  'awake': 407,
#  'add': 408,
#  'using': 409,
#  'break': 410,
#  'pain': 411,
#  'picture': 412,
#  'cry': 413,
#  'pics': 414,
#  'loved': 415,
#  'breakfast': 416,
#  'told': 417,
#  'fine': 418,
#  'facebook': 419,
#  'person': 420,
#  'boring': 421,
#  'change': 422,
#  'til': 423,
#  'wake': 424,
#  'goes': 425,
#  'seriously': 426,
#  'sunny': 427,
#  'update': 428,
#  'ass': 429,
#  'broke': 430,
#  'care': 431,
#  'bought': 432,
#  'starting': 433,
#  'dude': 434,
#  'gets': 435,
#  'lmao': 436,
#  'lucky': 437,
#  'open': 438,
#  'asleep': 439,
#  'season': 440,
#  'minutes': 441,
#  'june': 442,
#  'concert': 443,
#  'pay': 444,
#  'reply': 445,
#  'la': 446,
#  'sister': 447,
#  'called': 448,
#  'hungry': 449,
#  'month': 450,
#  'anyway': 451,
#  '9': 452,
#  'aw': 453,
#  'link': 454,
#  'bring': 455,
#  'crap': 456,
#  'afternoon': 457,
#  'site': 458,
#  'drive': 459,
#  'walk': 460,
#  '100': 461,
#  'shower': 462,
#  'heading': 463,
#  'text': 464,
#  'favorite': 465,
#  'sleeping': 466,
#  'train': 467,
#  'study': 468,
#  'instead': 469,
#  'fan': 470,
#  'yea': 471,
#  'xd': 472,
#  'ice': 473,
#  'bye': 474,
#  'e': 475,
#  'jealous': 476,
#  'enjoying': 477,
#  'red': 478,
#  'exams': 479,
#  'bout': 480,
#  'rock': 481,
#  'mother': 482,
#  'hoping': 483,
#  'definitely': 484,
#  'move': 485,
#  'wonderful': 486,
#  'mad': 487,
#  'brother': 488,
#  'high': 489,
#  'together': 490,
#  'dead': 491,
#  'city': 492,
#  'soooo': 493,
#  'dear': 494,
#  'problem': 495,
#  'sore': 496,
#  'fail': 497,
#  '0': 498,
#  'running': 499,
#  'congrats': 500,
#  '12': 501,
#  'homework': 502,
#  'sometimes': 503,
#  'l': 504,
#  'died': 505,
#  'finish': 506,
#  'nite': 507,
#  'youtube': 508,
#  'works': 509,
#  'means': 510,
#  'email': 511,
#  'goin': 512,
#  'ask': 513,
#  'movies': 514,
#  'fucking': 515,
#  'write': 516,
#  'album': 517,
#  'happened': 518,
#  'sigh': 519,
#  'suck': 520,
#  'drink': 521,
#  'set': 522,
#  'tea': 523,
#  'top': 524,
#  'town': 525,
#  'couple': 526,
#  'church': 527,
#  'cut': 528,
#  'laptop': 529,
#  'boys': 530,
#  'comes': 531,
#  'evening': 532,
#  'perfect': 533,
#  'ppl': 534,
#  'less': 535,
#  'loves': 536,
#  'ipod': 537,
#  'eyes': 538,
#  '20': 539,
#  'tour': 540,
#  'water': 541,
#  'months': 542,
#  'reason': 543,
#  'weird': 544,
#  'songs': 545,
#  'happen': 546,
#  'sound': 547,
#  'side': 548,
#  'gym': 549,
#  'nap': 550,
#  'fall': 551,
#  'visit': 552,
#  'dream': 553,
#  'ive': 554,
#  'final': 555,
#  'studying': 556,
#  'meeting': 557,
#  'cream': 558,
#  'listen': 559,
#  'test': 560,
#  'cat': 561,
#  'close': 562,
#  'ones': 563,
#  'dance': 564,
#  'seem': 565,
#  'tickets': 566,
#  'mood': 567,
#  'loving': 568,
#  'english': 569,
#  'interesting': 570,
#  'lil': 571,
#  'catch': 572,
#  'list': 573,
#  'store': 574,
#  'fb': 575,
#  'agree': 576,
#  'ate': 577,
#  'hang': 578,
#  '11': 579,
#  'turn': 580,
#  'writing': 581,
#  'knew': 582,
#  'story': 583,
#  'second': 584,
#  'fast': 585,
#  'worst': 586,
#  'pool': 587,
#  'moment': 588,
#  'clean': 589,
#  'ahh': 590,
#  'air': 591,
#  'word': 592,
#  'chocolate': 593,
#  'ride': 594,
#  'smile': 595,
#  'london': 596,
#  'awards': 597,
#  'saying': 598,
#  'page': 599,
#  'broken': 600,
#  'hmm': 601,
#  'yep': 602,
#  'moving': 603,
#  'wishing': 604,
#  'supposed': 605,
#  'unfortunately': 606,
#  'via': 607,
#  'worth': 608,
#  'photo': 609,
#  'dreams': 610,
#  'park': 611,
#  'throat': 612,
#  'three': 613,
#  'xxx': 614,
#  'wedding': 615,
#  'sunshine': 616,
#  'black': 617,
#  '1st': 618,
#  'driving': 619,
#  'pictures': 620,
#  'past': 621,
#  'cleaning': 622,
#  'sleepy': 623,
#  'forget': 624,
#  'da': 625,
#  'sent': 626,
#  'short': 627,
#  'sat': 628,
#  'horrible': 629,
#  'g': 630,
#  'gave': 631,
#  'myspace': 632,
#  'understand': 633,
#  'star': 634,
#  'jonas': 635,
#  'tweeting': 636,
#  'mum': 637,
#  'slow': 638,
#  'em': 639,
#  'k': 640,
#  'followfriday': 641,
#  'pick': 642,
#  'drinking': 643,
#  'plan': 644,
#  'mac': 645,
#  'college': 646,
#  'worse': 647,
#  'account': 648,
#  'chance': 649,
#  '15': 650,
#  'lady': 651,
#  'moon': 652,
#  'team': 653,
#  'whats': 654,
#  'green': 655,
#  'hugs': 656,
#  'wonder': 657,
#  'doesnt': 658,
#  'flight': 659,
#  'miley': 660,
#  'easy': 661,
#  'date': 662,
#  'rather': 663,
#  'longer': 664,
#  'fell': 665,
#  'hand': 666,
#  'special': 667,
#  'apparently': 668,
#  'mr': 669,
#  'upset': 670,
#  'bet': 671,
#  'holiday': 672,
#  'uk': 673,
#  'point': 674,
#  'updates': 675,
#  'scared': 676,
#  'tuesday': 677,
#  'nope': 678,
#  'bday': 679,
#  'flu': 680,
#  'cannot': 681,
#  'due': 682,
#  'vote': 683,
#  'huge': 684,
#  'spent': 685,
#  'plans': 686,
#  'wtf': 687,
#  'parents': 688,
#  'band': 689,
#  'mtv': 690,
#  'vacation': 691,
#  'words': 692,
#  'hanging': 693,
#  'plus': 694,
#  'ahhh': 695,
#  'earlier': 696,
#  'spend': 697,
#  'thx': 698,
#  'wondering': 699,
#  'website': 700,
#  'fair': 701,
#  'white': 702,
#  'forever': 703,
#  'body': 704,
#  'shame': 705,
#  'especially': 706,
#  'worry': 707,
#  'join': 708,
#  'bus': 709,
#  'line': 710,
#  'lazy': 711,
#  'idk': 712,
#  'david': 713,
#  'thursday': 714,
#  'message': 715,
#  'shows': 716,
#  'v': 717,
#  'stomach': 718,
#  'sadly': 719,
#  'lets': 720,
#  'thinks': 721,
#  'wear': 722,
#  'beer': 723,
#  'slept': 724,
#  'cake': 725,
#  'warm': 726,
#  'answer': 727,
#  'voice': 728,
#  'tom': 729,
#  'july': 730,
#  'looked': 731,
#  'google': 732,
#  'learn': 733,
#  'fans': 734,
#  'figure': 735,
#  'different': 736,
#  'bbq': 737,
#  'die': 738,
#  'inside': 739,
#  'havent': 740,
#  'support': 741,
#  'yummy': 742,
#  'meant': 743,
#  'eye': 744,
#  'chat': 745,
#  'number': 746,
#  'boyfriend': 747,
#  'rainy': 748,
#  'camera': 749,
#  'fix': 750,
#  'pizza': 751,
#  'airport': 752,
#  'photos': 753,
#  'except': 754,
#  'f': 755,
#  'safe': 756,
#  'met': 757,
#  'son': 758,
#  'episode': 759,
#  'small': 760,
#  'crying': 761,
#  'power': 762,
#  'dress': 763,
#  'sims': 764,
#  'liked': 765,
#  'graduation': 766,
#  'luv': 767,
#  'shop': 768,
#  'paper': 769,
#  'officially': 770,
#  '2day': 771,
#  'save': 772,
#  'tummy': 773,
#  'radio': 774,
#  'finals': 775,
#  'dm': 776,
#  'project': 777,
#  'laugh': 778,
#  'shirt': 779,
#  'shall': 780,
#  'garden': 781,
#  'decided': 782,
#  'proud': 783,
#  'worked': 784,
#  'apple': 785,
#  'absolutely': 786,
#  'games': 787,
#  'kid': 788,
#  'beat': 789,
#  'hubby': 790,
#  'felt': 791,
#  'alright': 792,
#  'chicken': 793,
#  'bike': 794,
#  'hug': 795,
#  'yup': 796,
#  'twilight': 797,
#  'kill': 798,
#  'shoes': 799,
#  'lonely': 800,
#  'blue': 801,
#  'cd': 802,
#  'wit': 803,
#  'woo': 804,
#  'gorgeous': 805,
#  'needed': 806,
#  'sign': 807,
#  'annoying': 808,
#  'road': 809,
#  'books': 810,
#  'exciting': 811,
#  'hospital': 812,
#  'keeps': 813,
#  'brothers': 814,
#  'card': 815,
#  'wednesday': 816,
#  'club': 817,
#  'babe': 818,
#  'played': 819,
#  'hmmm': 820,
#  'lame': 821,
#  'exactly': 822,
#  'packing': 823,
#  'xoxo': 824,
#  'french': 825,
#  'front': 826,
#  'case': 827,
#  'starts': 828,
#  'wine': 829,
#  'taken': 830,
#  'wishes': 831,
#  'near': 832,
#  'ouch': 833,
#  'scary': 834,
#  'living': 835,
#  'cos': 836,
#  'hates': 837,
#  'feet': 838,
#  'goodbye': 839,
#  'turned': 840,
#  'fact': 841,
#  'bro': 842,
#  'realized': 843,
#  'happens': 844,
#  'order': 845,
#  'knows': 846,
#  '2nd': 847,
#  'share': 848,
#  'isnt': 849,
#  'behind': 850,
#  'jus': 851,
#  'drunk': 852,
#  'business': 853,
#  'cup': 854,
#  'walking': 855,
#  'waking': 856,
#  'although': 857,
#  'yo': 858,
#  'service': 859,
#  'j': 860,
#  'mothers': 861,
#  'touch': 862,
#  'whatever': 863,
#  'download': 864,
#  'gettin': 865,
#  'question': 866,
#  'sold': 867,
#  'everybody': 868,
#  'pass': 869,
#  'clothes': 870,
#  'minute': 871,
#  'relaxing': 872,
#  'along': 873,
#  'hahah': 874,
#  'videos': 875,
#  'app': 876,
#  'alot': 877,
#  'giving': 878,
#  'wife': 879,
#  'lose': 880,
#  'mail': 881,
#  'vegas': 882,
#  'killing': 883,
#  'box': 884,
#  'random': 885,
#  'company': 886,
#  'posted': 887,
#  'sis': 888,
#  'fly': 889,
#  'sit': 890,
#  'film': 891,
#  'guitar': 892,
#  'lakers': 893,
#  'round': 894,
#  'hangover': 895,
#  'single': 896,
#  'fantastic': 897,
#  'revision': 898,
#  'staying': 899,
#  'terrible': 900,
#  'version': 901,
#  'passed': 902,
#  'enjoyed': 903,
#  'light': 904,
#  'web': 905,
#  'ahead': 906,
#  'comment': 907,
#  'interview': 908,
#  'indeed': 909,
#  'huh': 910,
#  'eh': 911,
#  'self': 912,
#  'gosh': 913,
#  'history': 914,
#  'plane': 915,
#  'bummed': 916,
#  'mins': 917,
#  'bitch': 918,
#  'dying': 919,
#  'ohh': 920,
#  'mommy': 921,
#  'aint': 922,
#  'asked': 923,
#  'daughter': 924,
#  'singing': 925,
#  'deal': 926,
#  'vip': 927,
#  'usually': 928,
#  'fml': 929,
#  'upload': 930,
#  'lately': 931,
#  'hun': 932,
#  'completely': 933,
#  'nights': 934,
#  'dark': 935,
#  'shoot': 936,
#  'bar': 937,
#  'peace': 938,
#  'bloody': 939,
#  'sexy': 940,
#  'cook': 941,
#  'cheese': 942,
#  'death': 943,
#  'disappointed': 944,
#  'nobody': 945,
#  'freaking': 946,
#  'dvd': 947,
#  'headed': 948,
#  'worried': 949,
#  'fat': 950,
#  'currently': 951,
#  'hotel': 952,
#  'camp': 953,
#  'extra': 954,
#  'changed': 955,
#  'sing': 956,
#  'ff': 957,
#  'bb': 958,
#  'pink': 959,
#  'wearing': 960,
#  'fingers': 961,
#  'awful': 962,
#  'country': 963,
#  'traffic': 964,
#  'quick': 965,
#  'yum': 966,
#  'others': 967,
#  'hold': 968,
#  'exhausted': 969,
#  'serious': 970,
#  '24': 971,
#  '50': 972,
#  'caught': 973,
#  'nick': 974,
#  'pissed': 975,
#  'art': 976,
#  'watchin': 977,
#  'blah': 978,
#  'daddy': 979,
#  'ran': 980,
#  'matter': 981,
#  'blood': 982,
#  'coz': 983,
#  'door': 984,
#  'dunno': 985,
#  'low': 986,
#  'spending': 987,
#  'pc': 988,
#  'chillin': 989,
#  'closed': 990,
#  'profile': 991,
#  'somewhere': 992,
#  'dang': 993,
#  'itunes': 994,
#  'hrs': 995,
#  'fixed': 996,
#  'maths': 997,
#  'nearly': 998,
#  'cousin': 999,
#  'nose': 1000,
#  ...}

# %%
vocab_size=len(tokenizer.word_index)+1
vocab_size
# Out:
# 290653

# %%
X_train = pad_sequences(tokenizer.texts_to_sequences(train_df.text), maxlen=300)
X_train
# Out:
# array([[    0,     0,     0, ...,  3008, 21821,   796],
#        [    0,     0,     0, ...,     7,   531,  2976],
#        [    0,     0,     0, ...,  9856,   874,   109],
#        ...,
#        [    0,     0,     0, ...,   262,   774,     1],
#        [    0,     0,     0, ...,   158, 17570,    11],
#        [    0,     0,     0, ...,     7, 32054,     7]], dtype=int32)

# %%
X_test = pad_sequences(tokenizer.texts_to_sequences(test_df.text), maxlen=300)
X_test
# Out:
# array([[    0,     0,     0, ...,   256,  1664,   199],
#        [    0,     0,     0, ...,  6190,  1790,    75],
#        [    0,     0,     0, ...,  4779,   806,   111],
#        ...,
#        [    0,     0,     0, ...,   572, 66636,  1913],
#        [    0,     0,     0, ...,   471,    82,   198],
#        [    0,     0,     0, ...,   203,   337,  5137]], dtype=int32)

# %%
y_train=train_df.target
y_train.head()
# Out:
# 1578903    Positive
# 51568      Negative
# 569210     Negative
# 71896      Negative
# 405089     Negative
# Name: target, dtype: object

# %%
y_test=test_df.target
y_test.head()
# Out:
# 448282     Negative
# 1475261    Positive
# 132529     Negative
# 182348     Negative
# 907614     Positive
# Name: target, dtype: object

# %%
labelencoder = LabelEncoder()
y_train = labelencoder.fit_transform(y_train)
y_test=labelencoder.fit_transform(y_test)

# %%
embedding_matrix = np.zeros((vocab_size, 300))
for word, i in tokenizer.word_index.items():
  if word in w2v_model.wv:
    embedding_matrix[i] = w2v_model.wv[word]
print(embedding_matrix.shape)
# Out:
# (290653, 300)

# %%
embedding_layer = Embedding(vocab_size, 300, weights=[embedding_matrix], input_length=300, trainable=False)

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
model = Sequential()
model.add(embedding_layer)
model.add(layers.SimpleRNN(100,dropout=0.2))
model.add(Dense(1, activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 300, 300)          87195900
#
#  simple_rnn_2 (SimpleRNN)    (None, 100)               40100
#
#  dense_2 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 87,236,101
# Trainable params: 40,201
# Non-trainable params: 87,195,900
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy',
              optimizer="adam",
              metrics=['accuracy'])

# %%
model_history=model.fit(X_train, y_train,batch_size=1024,epochs=10,validation_split=0.1,verbose=1)
# Out:
# Epoch 1/10
# 1125/1125 [==============================] - 281s 249ms/step - loss: 0.4633 - accuracy: 0.7800 - val_loss: 0.4539 - val_accuracy: 0.7864
# Epoch 2/10
# 1125/1125 [==============================] - 274s 244ms/step - loss: 0.4780 - accuracy: 0.7712 - val_loss: 0.4673 - val_accuracy: 0.7802
# Epoch 3/10
# 1125/1125 [==============================] - 274s 243ms/step - loss: 0.4668 - accuracy: 0.7802 - val_loss: 0.4571 - val_accuracy: 0.7863
# Epoch 4/10
# 1125/1125 [==============================] - 280s 249ms/step - loss: 0.4613 - accuracy: 0.7832 - val_loss: 0.4539 - val_accuracy: 0.7886
# Epoch 5/10
# 1125/1125 [==============================] - 283s 252ms/step - loss: 0.4584 - accuracy: 0.7845 - val_loss: 0.4518 - val_accuracy: 0.7899
# Epoch 6/10
# 1125/1125 [==============================] - 277s 246ms/step - loss: 0.4560 - accuracy: 0.7856 - val_loss: 0.4501 - val_accuracy: 0.7886
# Epoch 7/10
# 1125/1125 [==============================] - 280s 249ms/step - loss: 0.4535 - accuracy: 0.7867 - val_loss: 0.4470 - val_accuracy: 0.7907
# Epoch 8/10
# 1125/1125 [==============================] - 279s 248ms/step - loss: 0.4515 - accuracy: 0.7877 - val_loss: 0.4475 - val_accuracy: 0.7893
# Epoch 9/10
# 1125/1125 [==============================] - 280s 249ms/step - loss: 0.4496 - accuracy: 0.7884 - val_loss: 0.4439 - val_accuracy: 0.7923
# Epoch 10/10
# 1125/1125 [==============================] - 282s 250ms/step - loss: 0.4483 - accuracy: 0.7890 - val_loss: 0.4436 - val_accuracy: 0.7920

# %%
acc = model_history.history['accuracy']
val_acc = model_history.history['val_accuracy']
loss = model_history.history['loss']
val_loss = model_history.history['val_loss']
epochs=range(len(acc))

# %%
plt.plot(epochs,acc,label='Trainin_acc',color='blue')
plt.plot(epochs,val_acc,label='Validation_acc',color='red')
plt.legend()
plt.title("Training and Validation Accuracy")
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
plt.plot(epochs,loss,label='Training_loss',color='blue')
plt.plot(epochs,val_loss,label='Validation_loss',color='red')
plt.legend()
plt.title("Training and Validation loss")
# Out:
# Text(0.5, 1.0, 'Training and Validation loss')

# %%
def preprocess(text):
    review=re.sub('@\S+|https?:\S+|http?:\S|[^A-Za-z0-9]+',' ',text)
    review=review.lower()
    review=review.split()
    review=[word for word in review if not word in stop_words]
    print(review)
    review=pad_sequences(tokenizer.texts_to_sequences([review]), maxlen=300)
    return review

# %%
def prediction(review):
    review=preprocess(review)
    score=model.predict(review)
    score=score[0]
    if score<0.4:
        print("Negative")
    elif score>0.4 and score<0.6:
        print("Neutral")
    else:
        print("Positive")
    print(score)

# %%
prediction("the food is not bad")
# Out:
# ['food', 'not', 'bad']
# Positive
# [0.60012203]

# %%
prediction("the film was horrible")
# Out:
# ['film', 'horrible']
# Negative
# [0.09483673]

# %%
scores = model.predict(X_test, verbose=1, batch_size=1024)
y_pred=np.where(scores>0.5,1,0)
print(accuracy_score(y_pred,y_test))
# Out:
# 313/313 [==============================] - 11s 35ms/step
# 0.79163125
